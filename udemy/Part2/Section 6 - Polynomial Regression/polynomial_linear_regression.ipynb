# %% [markdown]
# # Data Preprocessing Template

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Will not split into training and test set since it's so small

# %% [markdown]
# Execute linear regression

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Training with the polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X)

# print(X_poly)

poly_regressor = LinearRegression()
poly_regressor.fit(X_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Visualizing linear regression

# %%
plt.scatter(X, y, color="red")
plt.plot(X, linear_regressor.predict((X)), color="blue")
plt.title("Predicated salaries (Linear Regression)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Visualize polynomial linear regression

# %%
plt.scatter(X, y, color="red")
plt.plot(X, poly_regressor.predict((X_poly)), color="blue")
plt.title("Predicated salaries (Polynomial Linear Regression)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# # Higher Degree Polynomial linear regression

# %%
poly_reg_4 = PolynomialFeatures(degree=4)
X_poly_4 = poly_reg_4.fit_transform(X)

poly_regressor_4 = LinearRegression()
poly_regressor_4.fit(X_poly_4, y)

plt.scatter(X, y, color="red")
plt.plot(X, poly_regressor_4.predict((X_poly_4)), color="blue")
plt.title("Predicated salaries (Polynomial Linear Regression)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Smooth out the curve

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
X_poly_grid = poly_reg_4.fit_transform(X_grid)

plt.scatter(X, y, color="red")
plt.plot(X_grid, poly_regressor_4.predict((X_poly_grid)), color="blue")
plt.title("Predicated salaries (Polynomial Linear Regression)")
plt.xlabel("Position Level")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Predicting salary with Linear Regression

# %%
predicted_salary = linear_regressor.predict([[6.5]])[0]
print(predicted_salary)

## Predicting salary with Polynomial Linear Regression
# Out:
# 330378.78787878784

# %%
predict_poly_4 = poly_reg_4.fit_transform([[6.5]])
# print((predict_poly_4))
predicted_salary_poly = poly_regressor_4.predict(predict_poly_4)[0]
print(predicted_salary_poly)
# Out:
# 158862.45265154913
